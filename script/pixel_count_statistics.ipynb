# %%
# getting weights of each features in different image folders
# the weights will be used in the model training

import geopandas as gpd
import pandas as pd
import shapely
import rasterio
import os
from pathlib import Path
import rioxarray
import fiona.transform
import numpy as np
from rasterio.warp import calculate_default_transform, reproject, Resampling
from shapely.geometry import Polygon
import skimage.draw
import numpy as np
import glob
import shutil
from tqdm import tqdm
import random
from os.path import dirname as up
path_cur = os.path.abspath(os.getcwd())

# %%
# Get the total pixel number of each class in the training set
data_dirs = os.path.join(up(path_cur), 'datasets')
data_dirs_dict = dict()

for data_dir in os.listdir(data_dirs):
    if os.path.isdir(os.path.join(data_dirs, data_dir)) and '.' not in data_dir:
        if not data_dir in data_dirs_dict.keys():
            data_dirs_dict[data_dir] = os.path.join(data_dirs, data_dir)

# %%
data_dirs_dict
# Out:
# {'Image_allyear_merged_512': '/rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512',
#  'Image_after_2010_merged_512': '/rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_after_2010_merged_512',
#  'Image_after_2010_merged_256': '/rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_after_2010_merged_256',
#  'Image_allyear_merged_256': '/rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_256',
#  'Image_allyear_merged_1024': '/rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_1024',
#  'Image_after_2010_merged_1024': '/rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_after_2010_merged_1024',
#  'Image_after_2010_VA_512': '/rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_after_2010_VA_512',
#  'Image_after_2010_VA_256': '/rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_after_2010_VA_256',
#  'Image_allyear_VA_512': '/rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_512',
#  'Image_allyear_VA_256': '/rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256'}

# %%
def count_pixel(img):
    
    src = rasterio.open(img)
    img_array = src.read(1)
    
    count_0 = np.count_nonzero(img_array == 0)
    count_1 = np.count_nonzero(img_array == 1)
    count_2 = np.count_nonzero(img_array == 2)
    count_3 = np.count_nonzero(img_array == 3)
    count_4 = np.count_nonzero(img_array == 4)
    
    return (count_0, count_1, count_2, count_3, count_4)

# %%
counting_weights = True

while counting_weights:
    
    counting_weights = False
    
    count_train_dict = dict()
    count_val_dict = dict()
    count_test_dict = dict()
    

    for key, val in tqdm(data_dirs_dict.items()):
        
        print("Working on {}".format(key))
        
        allfiles_train = [file for file in os.listdir(os.path.join(val, 'train')) if file.endswith('.tif')]
        allfiles_val = [file for file in os.listdir(os.path.join(val, 'val')) if file.endswith('.tif')]
        allfiles_test = [file for file in os.listdir(os.path.join(val, 'test')) if file.endswith('.tif')]
        
        if key not in count_train_dict.keys():
            
            print("Working on training data in ".format(key))
            
            count_train_dict[key] = np.zeros(5) # 5 classes including background 0
            
            for roi in allfiles_train:
                roi_file_mask = os.path.join(val, 'masks', roi)
                
                print('Processing {}'.format(roi_file_mask))
                
                counts = count_pixel(roi_file_mask)
                
                print('Counting is {}'.format(counts))
                count_train_dict[key] = np.add(count_train_dict[key], counts)


        if key not in count_val_dict.keys():
            
            print("Working on val data in ".format(key))
            
            count_val_dict[key] = np.zeros(5) # 5 classes including background 0
            
            for roi in allfiles_val:
                roi_file_mask = os.path.join(val, 'masks', roi)
                counts = count_pixel(roi_file_mask)
                count_val_dict[key] = np.add(count_val_dict[key], counts)
        
        
        if key not in count_test_dict.keys():
            
            print("Working on test data in ".format(key))
            
            count_test_dict[key] = np.zeros(5) # 5 classes including background 0
            
            for roi in allfiles_test:
                roi_file_mask = os.path.join(val, 'masks', roi)
                counts = count_pixel(roi_file_mask)
                count_test_dict[key] = np.add(count_test_dict[key], counts)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Working on Image_allyear_merged_512
# Working on training data in
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_31978255_wgs84_tile_5120-3584.tif
# Counting is (257909, 0, 0, 4235, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_31228345_wgs84_tile_2048-512.tif
# Counting is (261579, 0, 0, 565, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_30178315_wgs84_tile_1536-3584.tif
# Counting is (259305, 0, 0, 2839, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_29878210_wgs84_tile_5120-3584.tif
# Counting is (258271, 0, 0, 3873, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_26128030_wgs84_tile_4608-2048.tif
# Counting is (257064, 0, 0, 5080, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_31828375_wgs84_tile_4608-3584.tif
# Counting is (256627, 0, 0, 5517, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_27478015_wgs84_tile_5120-512.tif
# Counting is (261258, 0, 0, 886, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_31228345_wgs84_tile_2560-512.tif
# Counting is (261319, 0, 0, 825, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_24778000_wgs84_tile_5120-1024.tif
# Counting is (260888, 0, 0, 1256, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_25828210_wgs84_tile_2048-1536.tif
# Counting is (252654, 0, 0, 9490, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_28828345_wgs84_tile_4608-3584.tif
# Counting is (261262, 0, 0, 882, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_24028915_wgs84_tile_3584-512.tif
# Counting is (260236, 0, 0, 1908, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_29128330_wgs84_tile_1536-1536.tif
# Counting is (259881, 0, 0, 2263, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_31528240_wgs84_tile_5120-2048.tif
# Counting is (258162, 0, 0, 3982, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_26278855_wgs84_tile_4608-3584.tif
# Counting is (260975, 0, 0, 1169, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_27328270_wgs84_tile_1536-3584.tif
# Counting is (260812, 0, 0, 1332, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_32278255_wgs84_tile_4608-2048.tif
# Counting is (261410, 0, 0, 734, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_26428315_wgs84_tile_4608-2560.tif
# Counting is (260540, 0, 0, 1604, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_27178165_wgs84_tile_512-3072.tif
# Counting is (254936, 0, 0, 7208, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_27028585_wgs84_tile_3584-1536.tif
# Counting is (260958, 0, 0, 1186, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_31978375_wgs84_tile_2560-3072.tif
# Counting is (259316, 0, 0, 2828, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_26578615_wgs84_tile_1536-2048.tif
# Counting is (259751, 0, 0, 2393, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_24028915_wgs84_tile_4096-512.tif
# Counting is (259519, 0, 0, 2625, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_24778165_wgs84_tile_2560-3584.tif
# Counting is (260948, 0, 0, 1196, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_27178240_wgs84_tile_3584-2048.tif
# Counting is (257174, 0, 0, 4970, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_32278390_wgs84_tile_512-3584.tif
# Counting is (260843, 0, 0, 1301, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_29128330_wgs84_tile_512-1536.tif
# Counting is (259849, 0, 0, 2295, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_31977835_wgs84_tile_2048-3072.tif
# Counting is (260901, 0, 0, 1243, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_32428255_wgs84_tile_4096-1536.tif
# Counting is (259267, 0, 0, 2877, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_24028930_wgs84_tile_2048-1024.tif
# Counting is (260412, 0, 0, 1732, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_27178270_wgs84_tile_4608-1536.tif
# Counting is (260431, 0, 0, 1713, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_25378180_wgs84_tile_3584-1536.tif
# Counting is (260541, 0, 0, 1603, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_27028270_wgs84_tile_2048-3584.tif
# Counting is (257839, 0, 0, 4305, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_28828345_wgs84_tile_2048-3072.tif
# Counting is (260462, 0, 0, 1682, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_26278285_wgs84_tile_4608-2560.tif
# Counting is (258335, 0, 0, 3809, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_27328225_wgs84_tile_1024-512.tif
# Counting is (256197, 0, 0, 5947, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_29428195_wgs84_tile_3072-1536.tif
# Counting is (260281, 0, 0, 1863, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_26278285_wgs84_tile_4096-2048.tif
# Counting is (260048, 0, 0, 2096, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_25528165_wgs84_tile_2560-3072.tif
# Counting is (254396, 0, 0, 7748, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_26578270_wgs84_tile_512-3584.tif
# Counting is (260734, 0, 0, 1410, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_25378165_wgs84_tile_1536-3584.tif
# Counting is (260027, 0, 0, 2117, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_26278255_wgs84_tile_2560-1536.tif
# Counting is (258182, 0, 0, 3962, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_31528675_wgs84_tile_2048-3072.tif
# Counting is (260767, 0, 0, 1377, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_27178135_wgs84_tile_1024-1024.tif
# Counting is (255565, 0, 0, 6579, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_27927985_wgs84_tile_1536-3584.tif
# Counting is (259491, 0, 0, 2653, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_26727985_wgs84_tile_3584-1024.tif
# Counting is (261217, 0, 0, 927, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/groins_26428315_wgs84_tile_4608-3584.tif
# Counting is (252334, 0, 0, 9810, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1822_20_tile_4096-1536.tif
# Counting is (255092, 5170, 1882, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1437_40_tile_1024-1024.tif
# Counting is (249496, 7798, 4850, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_2418_10_tile_2560-1536.tif
# Counting is (256489, 3576, 2079, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_0515_30_tile_3072-1536.tif
# Counting is (260579, 0, 1565, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_9651_30_tile_4096-3584.tif
# Counting is (250010, 2426, 9708, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1523_20_tile_1024-2048.tif
# Counting is (247166, 4470, 10508, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_9866_10_tile_3584-3072.tif
# Counting is (256263, 262, 5619, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_N16_9726_40_tile_1024-2560.tif
# Counting is (256269, 1088, 4787, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_9882_30_tile_2048-1024.tif
# Counting is (255832, 4523, 1789, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_9647_40_tile_4608-1024.tif
# Counting is (257048, 5096, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_N16_9792_30_tile_512-2048.tif
# Counting is (255892, 6252, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_N16_8839_30_tile_1024-1024.tif
# Counting is (254041, 8103, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_2411_30_tile_1024-3072.tif
# Counting is (259129, 913, 2102, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_2756_10_tile_512-512.tif
# Counting is (258011, 0, 4133, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1447_40_tile_4096-1536.tif
# Counting is (242903, 11594, 7647, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_8607_10_tile_3584-1024.tif
# Counting is (261029, 1115, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_2769_10_tile_2048-1024.tif
# Counting is (258326, 3818, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_2603_10_tile_5120-1536.tif
# Counting is (243728, 0, 0, 0, 18416)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1815_40_tile_4608-512.tif
# Counting is (257921, 2853, 1370, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_9671_20_tile_3584-3584.tif
# Counting is (253985, 550, 7609, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_2803_40_tile_1536-1024.tif
# Counting is (258630, 3514, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1709_30_tile_3584-3072.tif
# Counting is (254975, 0, 7169, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1800_30_tile_3584-2048.tif
# Counting is (256402, 0, 5742, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1812_20_tile_2560-2560.tif
# Counting is (251863, 0, 7544, 0, 2737)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1800_40_tile_1024-1536.tif
# Counting is (260453, 0, 1691, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1609_10_tile_4608-3072.tif
# Counting is (257641, 4503, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_0547_20_tile_2560-1024.tif
# Counting is (257168, 1741, 3235, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1803_20_tile_2048-1024.tif
# Counting is (254451, 935, 6758, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_0582_20_tile_4096-3584.tif
# Counting is (259686, 2458, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1812_20_tile_4096-1536.tif
# Counting is (253480, 4393, 4271, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1607_30_tile_2048-1536.tif
# Counting is (255244, 0, 6900, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_2427_10_tile_2560-2560.tif
# Counting is (240993, 12715, 8436, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_2309_10_tile_2048-2048.tif
# Counting is (254212, 7932, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1531_30_tile_512-2048.tif
# Counting is (260198, 1946, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1407_30_tile_1024-1536.tif
# Counting is (259570, 2301, 273, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_9913_10_tile_2560-3584.tif
# Counting is (256227, 5917, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_0573_30_tile_4096-2048.tif
# Counting is (259939, 0, 2205, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_7791_20_tile_3072-1024.tif
# Counting is (254463, 7681, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_N16_8933_40_tile_4608-3584.tif
# Counting is (255717, 954, 5473, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_N16_9801_10_tile_4096-2560.tif
# Counting is (260628, 1516, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1308_10_tile_4096-2048.tif
# Counting is (259411, 2733, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_N16_8933_40_tile_4096-2048.tif
# Counting is (231035, 31109, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_2307_30_tile_1024-512.tif
# Counting is (243863, 16740, 1541, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_2892_10_tile_1536-3584.tif
# Counting is (260496, 0, 1648, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1720_10_tile_2048-3584.tif
# Counting is (260615, 0, 1529, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_9762_30_tile_4096-512.tif
# Counting is (257920, 0, 4224, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1407_30_tile_4096-2048.tif
# Counting is (244995, 0, 17149, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_3817_40_tile_2048-512.tif
# Counting is (259562, 2582, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1812_20_tile_2048-1536.tif
# Counting is (256914, 728, 4502, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_9866_10_tile_1024-3072.tif
# Counting is (259299, 2845, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_N16_9715_20_tile_2048-512.tif
# Counting is (259490, 2654, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1407_30_tile_1536-1024.tif
# Counting is (258075, 3715, 354, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_7791_30_tile_2048-3584.tif
# Counting is (257046, 5098, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_2418_10_tile_2560-3072.tif
# Counting is (239752, 14974, 7418, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_9647_40_tile_1536-2560.tif
# Counting is (256898, 0, 5246, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_N16_8998_40_tile_4608-3584.tif
# Counting is (259869, 2275, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1423_30_tile_4096-1024.tif
# Counting is (260117, 0, 2027, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_N16_8774_40_tile_1536-2560.tif
# Counting is (260365, 1779, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1429_10_tile_1536-2560.tif
# Counting is (251838, 1867, 8439, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1825_10_tile_4608-1024.tif
# Counting is (257962, 1986, 2196, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_9772_10_tile_4608-2048.tif
# Counting is (253502, 8642, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_7791_20_tile_1536-2048.tif
# Counting is (252642, 0, 9502, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1816_20_tile_512-1536.tif
# Counting is (260283, 0, 1861, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_N26_0649_30_tile_4096-3072.tif
# Counting is (257340, 777, 4027, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1703_30_tile_4608-1024.tif
# Counting is (258835, 0, 3309, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1437_40_tile_512-1024.tif
# Counting is (248792, 10847, 2505, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1429_40_tile_4608-2048.tif
# Counting is (258824, 0, 3320, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1812_10_tile_3072-3072.tif
# Counting is (260051, 2093, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1803_30_tile_512-3584.tif
# Counting is (259064, 3080, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1825_10_tile_4608-1536.tif
# Counting is (252685, 6122, 3337, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_9651_30_tile_3584-3584.tif
# Counting is (254681, 1731, 5732, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1834_10_tile_2048-3072.tif
# Counting is (255855, 0, 6289, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_N16_8839_30_tile_2560-1024.tif
# Counting is (257987, 4157, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1815_30_tile_4096-1024.tif
# Counting is (256806, 2796, 2542, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1822_30_tile_1024-2048.tif
# Counting is (259833, 0, 869, 1442, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1438_20_tile_1024-512.tif
# Counting is (243336, 15624, 3184, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1404_40_tile_4096-3072.tif
# Counting is (260025, 2119, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_N16_8942_30_tile_1536-3072.tif
# Counting is (253293, 8851, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1523_30_tile_1024-2048.tif
# Counting is (253910, 0, 8234, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_9671_20_tile_2560-3072.tif
# Counting is (255266, 3726, 3152, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_9896_30_tile_4608-3072.tif
# Counting is (259459, 2685, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1719_20_tile_2560-2560.tif
# Counting is (246962, 0, 8597, 0, 6585)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1822_30_tile_2560-1536.tif
# Counting is (258189, 0, 3955, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1479_30_tile_1024-512.tif
# Counting is (251753, 10253, 138, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1510_30_tile_512-512.tif
# Counting is (260106, 2038, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_9896_30_tile_4608-3584.tif
# Counting is (260300, 1844, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_2769_10_tile_2560-1536.tif
# Counting is (259808, 2336, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_2769_20_tile_4096-1536.tif
# Counting is (252504, 1054, 8586, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1417_20_tile_2560-512.tif
# Counting is (254828, 2820, 4496, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1826_40_tile_3584-2560.tif
# Counting is (259381, 2677, 86, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_9637_30_tile_512-2048.tif
# Counting is (260288, 1856, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_9646_30_tile_4608-3072.tif
# Counting is (255360, 3382, 3402, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_N16_8813_40_tile_512-3072.tif
# Counting is (260717, 0, 1427, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_N26_0649_10_tile_512-3584.tif
# Counting is (249248, 8898, 3998, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1407_30_tile_4096-3072.tif
# Counting is (258635, 1849, 1660, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_9839_30_tile_1024-1536.tif
# Counting is (261048, 1096, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1503_10_tile_3072-3584.tif
# Counting is (256853, 0, 5291, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_N16_8799_40_tile_2560-1024.tif
# Counting is (260372, 1772, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_2510_20_tile_3072-3072.tif
# Counting is (255604, 0, 6540, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_N16_8839_30_tile_3584-1024.tif
# Counting is (245469, 7170, 1397, 0, 8108)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1824_30_tile_2048-512.tif
# Counting is (257367, 4777, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1413_30_tile_512-1024.tif
# Counting is (259862, 2282, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1414_40_tile_3584-2048.tif
# Counting is (257851, 4293, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1721_10_tile_3584-3584.tif
# Counting is (257394, 0, 4750, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1443_10_tile_3584-2560.tif
# Counting is (256650, 5494, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_9680_20_tile_3072-512.tif
# Counting is (254377, 0, 7767, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1825_30_tile_2560-2560.tif
# Counting is (260268, 0, 1876, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1479_30_tile_4608-512.tif
# Counting is (257280, 4864, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_9770_30_tile_2560-2048.tif
# Counting is (258236, 0, 3908, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_N16_8972_10_tile_2048-1536.tif
# Counting is (253538, 3897, 4709, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_N16_9800_30_tile_2048-3584.tif
# Counting is (260895, 0, 1249, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_N26_0639_30_tile_2048-3584.tif
# Counting is (260236, 1650, 258, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_N17_8090_40_tile_3584-3584.tif
# Counting is (244605, 3199, 14340, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_9865_20_tile_4608-2048.tif
# Counting is (259924, 2220, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1447_10_tile_2560-3072.tif
# Counting is (251283, 2666, 8195, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1437_10_tile_2048-1024.tif
# Counting is (251288, 2661, 8195, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_N16_8942_20_tile_2560-1024.tif
# Counting is (257465, 4679, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1510_30_tile_4096-3072.tif
# Counting is (258121, 3066, 957, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1629_30_tile_3072-3584.tif
# Counting is (250513, 11631, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1407_30_tile_3072-1024.tif
# Counting is (259891, 2253, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1719_10_tile_2048-512.tif
# Counting is (256455, 0, 5689, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1524_40_tile_512-512.tif
# Counting is (250323, 9780, 2041, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_2769_10_tile_4608-512.tif
# Counting is (256369, 5775, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_9772_10_tile_4096-2048.tif
# Counting is (253277, 8867, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_2424_10_tile_512-3072.tif
# Counting is (256864, 2566, 2714, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1815_40_tile_3584-2560.tif
# Counting is (253517, 8627, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_8694_10_tile_4608-512.tif
# Counting is (260847, 1297, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1823_30_tile_3584-3072.tif
# Counting is (260257, 1887, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1423_30_tile_3584-3584.tif
# Counting is (251817, 4857, 5470, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_8607_10_tile_3072-1536.tif
# Counting is (259891, 2253, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1429_40_tile_3584-3072.tif
# Counting is (258551, 0, 3593, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1413_30_tile_1024-512.tif
# Counting is (255714, 6430, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_2743_10_tile_4096-1024.tif
# Counting is (258787, 3357, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_9772_40_tile_3584-512.tif
# Counting is (257248, 4896, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_9645_30_tile_3072-2560.tif
# Counting is (257519, 4625, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_2427_10_tile_512-2560.tif
# Counting is (245744, 14186, 2214, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_2872_30_tile_5120-512.tif
# Counting is (260035, 2109, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_2893_40_tile_3072-512.tif
# Counting is (260781, 1363, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1479_40_tile_3072-1536.tif
# Counting is (258215, 3929, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_N16_8974_40_tile_512-1536.tif
# Counting is (255334, 2782, 4028, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1521_30_tile_4608-1536.tif
# Counting is (249437, 4594, 8113, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1447_40_tile_3072-3072.tif
# Counting is (227925, 4987, 29232, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1427_20_tile_3584-1536.tif
# Counting is (259234, 2910, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1812_10_tile_4608-1024.tif
# Counting is (256854, 0, 5290, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1479_40_tile_4608-3584.tif
# Counting is (256687, 5457, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_9884_30_tile_4608-3584.tif
# Counting is (257025, 0, 5119, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1437_10_tile_4096-2560.tif
# Counting is (247604, 10167, 4373, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1834_20_tile_4608-1024.tif
# Counting is (258633, 0, 3511, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_9884_10_tile_512-3584.tif
# Counting is (258032, 1521, 2591, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1833_20_tile_2560-2560.tif
# Counting is (260727, 0, 1417, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1823_20_tile_1024-1024.tif
# Counting is (258230, 0, 3914, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1635_10_tile_512-3072.tif
# Counting is (248444, 0, 13700, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_9647_40_tile_1024-3584.tif
# Counting is (260426, 1473, 245, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_N16_9726_20_tile_4096-1536.tif
# Counting is (257913, 3379, 852, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_N16_9792_30_tile_5120-512.tif
# Counting is (259715, 2429, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1423_30_tile_1024-3072.tif
# Counting is (255249, 4420, 2475, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1709_30_tile_512-1024.tif
# Counting is (258969, 0, 3175, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1826_40_tile_1024-1024.tif
# Counting is (258377, 0, 0, 3767, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1713_20_tile_512-1536.tif
# Counting is (259188, 0, 2956, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1447_10_tile_512-2560.tif
# Counting is (258856, 0, 3288, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1407_30_tile_1024-1024.tif
# Counting is (256902, 910, 4332, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1710_30_tile_3584-512.tif
# Counting is (245084, 12790, 4270, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_7791_30_tile_1536-3584.tif
# Counting is (257197, 4947, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_0541_30_tile_2560-512.tif
# Counting is (258924, 3220, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1426_40_tile_4608-2048.tif
# Counting is (255339, 4046, 2759, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_9622_10_tile_2560-3584.tif
# Counting is (260435, 1709, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1813_30_tile_512-1024.tif
# Counting is (259525, 0, 2619, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S13_9772_40_tile_2048-512.tif
# Counting is (257434, 4710, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1409_10_tile_512-1024.tif
# Counting is (252245, 0, 9899, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_N16_8999_10_tile_2048-512.tif
# Counting is (260696, 1448, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_2721_20_tile_1024-512.tif
# Counting is (256513, 3522, 0, 0, 2109)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1807_20_tile_4608-3584.tif
# Counting is (251102, 0, 8749, 0, 2293)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_N16_9745_20_tile_1536-2560.tif
# Counting is (255696, 0, 6448, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_N16_8805_10_tile_2048-2048.tif
# Counting is (249723, 12421, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1488_20_tile_1024-2560.tif
# Counting is (259382, 2762, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1513_30_tile_4096-3584.tif
# Counting is (256217, 0, 5927, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_0566_10_tile_512-1536.tif
# Counting is (255768, 6376, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_N16_9784_10_tile_2560-512.tif
# Counting is (259970, 0, 2174, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1706_30_tile_1024-1536.tif
# Counting is (254314, 1867, 5963, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_N16_8805_10_tile_2560-1024.tif
# Counting is (249723, 11423, 998, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1617_20_tile_512-3072.tif
# Counting is (259925, 0, 2219, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_2803_40_tile_1536-512.tif
# Counting is (260551, 1593, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1719_10_tile_3072-512.tif
# Counting is (247748, 0, 14396, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1719_20_tile_1536-3072.tif
# Counting is (252300, 730, 9114, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1833_20_tile_512-512.tif
# Counting is (259989, 0, 2155, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_N16_9727_20_tile_2048-1024.tif
# Counting is (257150, 4994, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1807_20_tile_1536-2560.tif
# Counting is (249504, 0, 6471, 6169, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1833_10_tile_2048-512.tif
# Counting is (256582, 0, 1434, 1321, 2807)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1703_30_tile_3072-1024.tif
# Counting is (254794, 7350, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1825_10_tile_3072-1024.tif
# Counting is (245883, 9649, 5336, 0, 1276)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_merged_512/masks/shoreline_DO_S23_1708_30_tile_512-3072.tif
# Counting is (250795, 11349, 0, 0, 0)
# ...
# Counting is (62209, 0, 3327, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_2894_40_tile_2048-1536.tif
# Counting is (61368, 0, 0, 4168, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_N16_8995_30_tile_3840-4096.tif
# Counting is (59611, 2747, 3178, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S13_9441_40_tile_1280-3072.tif
# Counting is (64311, 0, 1225, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_N16_9802_30_tile_1792-3584.tif
# Counting is (60631, 3554, 1351, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_N16_9802_30_tile_512-2304.tif
# Counting is (62743, 0, 2793, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1811_30_tile_256-512.tif
# Counting is (60102, 0, 1868, 3566, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_2426_20_tile_2816-256.tif
# Counting is (62918, 929, 1689, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1409_20_tile_256-4096.tif
# Counting is (63001, 0, 612, 0, 1923)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S13_7697_30_tile_3584-1024.tif
# Counting is (64846, 0, 690, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_N16_8804_40_tile_2560-2560.tif
# Counting is (59093, 4733, 1710, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1570_10_tile_3072-768.tif
# Counting is (64402, 0, 1134, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1488_30_tile_2304-2048.tif
# Counting is (59230, 3756, 2550, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_2604_10_tile_4096-2304.tif
# Counting is (59769, 0, 0, 0, 5767)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S13_7791_40_tile_1792-2560.tif
# Counting is (63841, 1695, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1835_20_tile_1024-512.tif
# Counting is (59275, 0, 4863, 0, 1398)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_2870_20_tile_2304-1536.tif
# Counting is (62848, 2688, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1719_20_tile_768-4096.tif
# Counting is (63029, 452, 2055, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1816_10_tile_2304-2048.tif
# Counting is (63604, 1932, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_2418_40_tile_1792-2560.tif
# Counting is (54664, 8257, 2615, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_0518_30_tile_768-3584.tif
# Counting is (61790, 2686, 1060, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1709_30_tile_5376-768.tif
# Counting is (63478, 0, 2058, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_2510_20_tile_3584-3584.tif
# Counting is (62412, 0, 3124, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1705_20_tile_5376-256.tif
# Counting is (63182, 2354, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1707_20_tile_5120-3072.tif
# Counting is (62462, 3074, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_2411_30_tile_3072-1024.tif
# Counting is (63813, 1723, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1510_30_tile_768-768.tif
# Counting is (63498, 2038, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S13_9893_40_tile_256-1792.tif
# Counting is (64755, 781, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_2769_30_tile_2048-768.tif
# Counting is (64164, 0, 1372, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_0555_40_tile_5120-3072.tif
# Counting is (58605, 2711, 4220, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_0541_30_tile_256-1280.tif
# Counting is (62979, 2557, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1803_40_tile_4608-768.tif
# Counting is (63815, 1721, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_N16_8840_20_tile_3328-3328.tif
# Counting is (64785, 0, 751, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1723_10_tile_1024-1024.tif
# Counting is (60647, 3825, 1064, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_2510_20_tile_2816-3072.tif
# Counting is (62201, 0, 3335, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S13_9772_10_tile_5120-1792.tif
# Counting is (64044, 1492, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_N26_0649_20_tile_3584-2816.tif
# Counting is (62889, 0, 2647, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1823_20_tile_5120-2304.tif
# Counting is (62480, 1270, 1786, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1825_20_tile_3328-1280.tif
# Counting is (59866, 5440, 230, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1404_40_tile_4352-3072.tif
# Counting is (63417, 2119, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1804_10_tile_4608-4096.tif
# Counting is (63167, 2369, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1811_20_tile_4352-1536.tif
# Counting is (55918, 0, 3152, 6466, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_0556_10_tile_4352-2304.tif
# Counting is (62953, 0, 2583, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_N16_9800_30_tile_4096-1024.tif
# Counting is (59536, 1876, 4124, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_2415_40_tile_3584-3840.tif
# Counting is (64066, 1470, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1812_30_tile_1280-3328.tif
# Counting is (57215, 0, 3342, 4979, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1703_40_tile_3584-768.tif
# Counting is (63458, 2078, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1802_40_tile_1536-2560.tif
# Counting is (64256, 1280, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S13_9858_40_tile_2816-2304.tif
# Counting is (62613, 826, 2097, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_N16_8893_40_tile_3328-2816.tif
# Counting is (64930, 606, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1489_30_tile_5120-3840.tif
# Counting is (62508, 0, 3028, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1413_20_tile_5120-2304.tif
# Counting is (62089, 3447, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_0538_20_tile_4096-256.tif
# Counting is (62605, 2931, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1513_20_tile_2560-768.tif
# Counting is (58994, 2635, 3907, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1503_10_tile_4096-2304.tif
# Counting is (62417, 0, 3119, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1513_20_tile_2304-2304.tif
# Counting is (58975, 5840, 721, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1429_40_tile_4864-1536.tif
# Counting is (62795, 1369, 1372, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1834_10_tile_2816-3072.tif
# Counting is (60795, 0, 4741, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1407_30_tile_1792-768.tif
# Counting is (63474, 75, 1987, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1824_10_tile_1536-1792.tif
# Counting is (61227, 0, 4309, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1570_10_tile_4096-4096.tif
# Counting is (64348, 1188, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1629_40_tile_768-256.tif
# Counting is (63256, 0, 2280, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S13_9336_30_tile_4864-256.tif
# Counting is (64079, 0, 1457, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1823_40_tile_2048-2816.tif
# Counting is (63657, 1879, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1822_30_tile_1280-2304.tif
# Counting is (64667, 0, 869, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_N16_8822_20_tile_2304-3584.tif
# Counting is (61823, 0, 3713, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1812_20_tile_4096-1280.tif
# Counting is (57388, 5329, 2819, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_0564_30_tile_1280-2304.tif
# Counting is (63090, 1647, 799, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1570_40_tile_2816-3840.tif
# Counting is (62289, 2132, 1115, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_N16_9727_10_tile_1792-1536.tif
# Counting is (63816, 1720, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1826_40_tile_1024-1024.tif
# Counting is (61769, 0, 0, 3767, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_N16_8839_30_tile_3584-1280.tif
# Counting is (59548, 1115, 1397, 0, 3476)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_2722_10_tile_2816-1024.tif
# Counting is (61447, 0, 4089, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_2897_30_tile_4096-1792.tif
# Counting is (61281, 1062, 3193, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1423_30_tile_2560-2560.tif
# Counting is (63637, 1899, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_N16_8823_10_tile_512-2304.tif
# Counting is (60995, 3028, 1513, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_N16_8838_10_tile_2304-3584.tif
# Counting is (63657, 1879, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_3807_20_tile_4608-3072.tif
# Counting is (61642, 3894, 0, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_2433_20_tile_3072-3328.tif
# Counting is (60755, 1462, 3319, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S23_1835_20_tile_256-2560.tif
# Counting is (61987, 0, 3549, 0, 0)
# Processing /rapids/notebooks/sciclone/geograd/Miranda/github/shoreline_structure/datasets/Image_allyear_VA_256/masks/shoreline_DO_S13_9641_10_tile_3584-768.tif
# Counting is (62854, 1318, 1364, 0, 0)
# Working on val data in
# Working on test data in
# 100%|██████████| 10/10 [03:44<00:00, 22.48s/it]

# %%
count_train_dict
# Out:
# {'Image_allyear_merged_512': array([3.19216492e+08, 4.14880300e+06, 3.77854800e+06, 2.24932000e+05,
#         3.11225000e+05]),
#  'Image_after_2010_merged_512': array([1.5546088e+08, 1.9051890e+06, 1.8110280e+06, 2.2042800e+05,
#         2.4817100e+05]),
#  'Image_after_2010_merged_256': array([37965447.,   717437.,   924223.,   379316.,   187145.]),
#  'Image_allyear_merged_256': array([69758536.,  1806539.,  1704174.,   374952.,   214871.]),
#  'Image_allyear_merged_1024': array([9.01530355e+08, 5.93995600e+06, 5.37768500e+06, 1.21750000e+05,
#         3.39950000e+05]),
#  'Image_after_2010_merged_1024': array([3.6814858e+08, 2.5507520e+06, 2.2371310e+06, 1.2517600e+05,
#         2.3141700e+05]),
#  'Image_after_2010_VA_512': array([1.43280007e+08, 1.90518900e+06, 1.81102800e+06, 8.05330000e+04,
#         2.48171000e+05]),
#  'Image_after_2010_VA_256': array([31105858.,   717437.,   924223.,    95481.,   187145.]),
#  'Image_allyear_VA_512': array([3.07035619e+08, 4.14880300e+06, 3.77854800e+06, 8.50370000e+04,
#         3.11225000e+05]),
#  'Image_allyear_VA_256': array([62898947.,  1806539.,  1704174.,    91117.,   214871.])}

# %%
count_val_dict
# Out:
# {'Image_allyear_merged_512': array([8.9163701e+07, 1.1399860e+06, 9.2449400e+05, 1.8005700e+05,
#         8.0018000e+04]),
#  'Image_after_2010_merged_512': array([48310279.,   480706.,   498131.,   204321.,    51779.]),
#  'Image_after_2010_merged_256': array([14675054.,   164872.,   225847.,   267960.,    67227.]),
#  'Image_allyear_merged_256': array([22668066.,   406597.,   427725.,   270849.,    81867.]),
#  'Image_allyear_merged_1024': array([2.33763874e+08, 1.65217400e+06, 1.43050400e+06, 5.30310000e+04,
#         7.85930000e+04]),
#  'Image_after_2010_merged_1024': array([1.00369836e+08, 7.02007000e+05, 5.55985000e+05, 3.47780000e+04,
#         4.92660000e+04]),
#  'Image_after_2010_VA_512': array([3.5897933e+07, 4.8070600e+05, 4.9813100e+05, 3.3755000e+04,
#         5.1779000e+04]),
#  'Image_after_2010_VA_256': array([7768459.,  164872.,  225847.,   31131.,   67227.]),
#  'Image_allyear_VA_512': array([7.6751355e+07, 1.1399860e+06, 9.2449400e+05, 9.4910000e+03,
#         8.0018000e+04]),
#  'Image_allyear_VA_256': array([15761471.,   406597.,   427725.,    34020.,    81867.])}

# %%
count_test_dict
# Out:
# {'Image_allyear_merged_512': array([9.2442371e+07, 8.6514500e+05, 8.8511900e+05, 3.5553500e+05,
#         8.5814000e+04]),
#  'Image_after_2010_merged_512': array([56348439.,   452701.,   443461.,   331577.,    95502.]),
#  'Image_after_2010_merged_256': array([20647149.,   184556.,   173911.,   571480.,    49784.]),
#  'Image_allyear_merged_256': array([27680744.,   391008.,   330605.,   579735.,    50356.]),
#  'Image_allyear_merged_1024': array([2.19802259e+08, 1.30526500e+06, 1.04514000e+06, 9.72300000e+04,
#         4.82180000e+04]),
#  'Image_after_2010_merged_1024': array([1.01302222e+08, 6.22282000e+05, 6.26021000e+05, 1.09679000e+05,
#         1.00244000e+05]),
#  'Image_after_2010_VA_512': array([3.176479e+07, 4.527010e+05, 4.434610e+05, 1.154600e+04,
#         9.550200e+04]),
#  'Image_after_2010_VA_256': array([6916659.,  184556.,  173911.,   15122.,   49784.]),
#  'Image_allyear_VA_512': array([6.7858722e+07, 8.6514500e+05, 8.8511900e+05, 3.5504000e+04,
#         8.5814000e+04]),
#  'Image_allyear_VA_256': array([13950254.,   391008.,   330605.,    23377.,    50356.])}

# %%
pixel_train_weights = dict()

for key, item in count_train_dict.items():
    
    if key not in pixel_train_weights.keys():
        pixel_train_weights[key] = item[1:] / np.sum(item[1:]) # proportion of the class in this dataset, not count background

# %%
pixel_val_weights = dict()

for key, item in count_val_dict.items():
    
    if key not in pixel_val_weights.keys():
        pixel_val_weights[key] = item[1:] / np.sum(item[1:]) # proportion of the class in this dataset, not count background

# %%
pixel_test_weights = dict()

for key, item in count_test_dict.items():
    
    if key not in pixel_test_weights.keys():
        pixel_test_weights[key] = item[1:] / np.sum(item[1:]) # proportion of the class in this dataset, not count background

# %%
pixel_train_weights
# Out:
# {'Image_allyear_merged_512': array([0.49019898, 0.44645175, 0.02657669, 0.03677258]),
#  'Image_after_2010_merged_512': array([0.45526231, 0.43276168, 0.05267328, 0.05930273]),
#  'Image_after_2010_merged_256': array([0.32490837, 0.41855632, 0.17178225, 0.08475305]),
#  'Image_allyear_merged_256': array([0.44056167, 0.41559786, 0.09143975, 0.05240071]),
#  'Image_allyear_merged_1024': array([0.50426896, 0.4565353 , 0.01033589, 0.02885985]),
#  'Image_after_2010_merged_1024': array([0.49582348, 0.43486081, 0.02433212, 0.04498359]),
#  'Image_after_2010_VA_512': array([0.47100772, 0.44772889, 0.01990966, 0.06135373]),
#  'Image_after_2010_VA_256': array([0.37283283, 0.48029399, 0.04961892, 0.09725425]),
#  'Image_allyear_VA_512': array([0.49843776, 0.45395527, 0.01021636, 0.03739061]),
#  'Image_allyear_VA_256': array([0.47332474, 0.44650446, 0.02387324, 0.05629757])}

# %%
pixel_val_weights
# Out:
# {'Image_allyear_merged_512': array([0.49041042, 0.39770795, 0.0774587 , 0.03442293]),
#  'Image_after_2010_merged_512': array([0.38925548, 0.40336552, 0.16545055, 0.04192845]),
#  'Image_after_2010_merged_256': array([0.22712583, 0.31112431, 0.3691387 , 0.09261116]),
#  'Image_allyear_merged_256': array([0.34253074, 0.36032966, 0.22817214, 0.06896746]),
#  'Image_allyear_merged_1024': array([0.51400708, 0.44504343, 0.01649845, 0.02445103]),
#  'Image_after_2010_merged_1024': array([0.52309103, 0.41428471, 0.02591436, 0.03670989]),
#  'Image_after_2010_VA_512': array([0.45163388, 0.46800505, 0.03171357, 0.04864751]),
#  'Image_after_2010_VA_256': array([0.33710847, 0.46178209, 0.06365255, 0.13745688]),
#  'Image_allyear_VA_512': array([0.52924411, 0.42920089, 0.00440624, 0.03714875]),
#  'Image_allyear_VA_256': array([0.4279027 , 0.45013781, 0.03580265, 0.08615683])}

# %%
pixel_test_weights
# Out:
# {'Image_allyear_merged_512': array([0.39475263, 0.40386647, 0.16222527, 0.03915564]),
#  'Image_after_2010_merged_512': array([0.34211531, 0.33513245, 0.25057945, 0.07217279]),
#  'Image_after_2010_merged_256': array([0.18837416, 0.17750893, 0.58330297, 0.05081395]),
#  'Image_allyear_merged_256': array([0.28927043, 0.24458387, 0.42889198, 0.03725372]),
#  'Image_allyear_merged_1024': array([0.52297351, 0.41875062, 0.03895662, 0.01931925]),
#  'Image_after_2010_merged_1024': array([0.42673907, 0.42930314, 0.07521399, 0.0687438 ]),
#  'Image_after_2010_VA_512': array([0.45125248, 0.44204205, 0.01150906, 0.09519642]),
#  'Image_after_2010_VA_256': array([0.43591821, 0.4107749 , 0.03571791, 0.11758898]),
#  'Image_allyear_VA_512': array([0.46225332, 0.47292558, 0.01897005, 0.04585105]),
#  'Image_allyear_VA_256': array([0.49162   , 0.41567444, 0.02939224, 0.06331333])}

# %%
import pandas as pd
import functools as ft

# %%
# get the percentage of the pixels at each dataset
def get_percent(dic, mode='train'):
    
    df = pd.DataFrame.from_dict(dic).T.rename_axis('dataset').reset_index().round(2)
    col_nm = '{}_percent'.format(mode)
    df[col_nm] = df.apply(lambda x: str(x[0]) + '/' + str(x[1]) + '/' + str(x[2]) + '/' + str(x[3]), axis=1)
    del df[0]
    del df[1]
    del df[2]
    del df[3]
    
    return df

def get_count(dic, mode='train'):
    
    df = pd.DataFrame.from_dict(dic).T.rename_axis('dataset').reset_index()
    col_nm = '{}_count'.format(mode)
    df[col_nm] = df.apply(lambda x: str(x[1]) + '/' + str(x[2]) + '/' + str(x[3]) + '/' + str(x[4]), axis=1)
    
    del df[0]
    del df[1]
    del df[2]
    del df[3]
    del df[4]

    return df

# %%
# get pixel count (background is not included)s
train_count = get_count(count_train_dict, mode='train')
val_count = get_count(count_val_dict, mode='val')
test_count = get_count(count_test_dict, mode='test')

# get pixel percentage (background is not included)
train_df = get_percent(pixel_train_weights, mode='train')
val_df = get_percent(pixel_val_weights, mode='val')
test_df = get_percent(pixel_test_weights, mode='test')

# %%
dfs = [train_count, val_count, test_count, train_df, val_df, test_df]
df_final = ft.reduce(lambda left, right: pd.merge(left, right, on='dataset'), dfs)

# %%
df_final.to_csv(os.path.join(up(path_cur), 'pixel_count_statistics.csv'), encoding='utf-8', sep=',', index=False)
